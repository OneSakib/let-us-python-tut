# %%
# class Department:
#     def set_department(self):
#         self.__id = input("Enter Dep id")
#         self.__name = input("Dep Name")

#     def display(self):
#         print("Dep", self.__id)
#         print("Dep", self.__name)


# class Employee:
#     def set_employee(self):
#         self.__eid = input("Enter Id")
#         self.__ename = input("name")
#         self.__dobj = Department()
#         self.__dobj.set_department()

#     def display(self):
#         print(self.__eid)
#         print(self.__ename)
#         self.__dobj.display()


# if __name__ == '__main__':
#     emp = Employee()
#     emp.set_employee()
#     emp.display()


# inheritance


# class Index:
#     def __init__(self) -> None:
#         self.count = 0

#     def display(self):
#         print("Count: ", self.count)

#     def incr(self):
#         self.count += 1


# class NewIndex(Index):
#     def __init__(self) -> None:
#         super().__init__()

#     def decr(self):
#         self.count -= 1


# i = NewIndex()
# i.incr()
# i.incr()
# i.incr()
# i.incr()
# i.incr()
# i.display()
# i.decr()
# i.display()


# Access specifier


# class Base:
#     def __init__(self) -> None:
#         self.i = 10
#         self._a = 3.14
#         self.__s = 'Hello'

#     def display(self):
#         print(self.i, self._a, self.__s)


# class Derived(Base):
#     def __init__(self) -> None:
#         super().__init__()
#         self.i = 100
#         self._a = 31.44
#         # self.__s = 'Good Morning'
#         self.j = 20
#         self._b = 6.28
#         self.__ss = 'Hi'

#     def display(self):
#         super().display()
#         print(self.i, self._a)
#         print(self.j, self._b, self.__ss)


# bobj = Base()
# bobj.display()
# print(bobj.i)
# print(bobj._a)
# print(bobj.__s)
# dobj=Derived()
# dobj.display()
# print(dobj.i)
# print(dobj._a)
# # print(dobj.__s)
# print(dobj.j)
# print(dobj._b)
# print(dobj.__ss)


# Multiple inheritance


# class Product:
#     def __init__(self) -> None:
#         self.__title = input("Enter title: ")
#         self.__price = input("Enter price: ")

#     def display(self):
#         print(self.__title, self.__price)


# class Sales:
#     def __init__(self) -> None:
#         self.__sales_figures = [int(x) for x in input(
#             "Enter Sales figures: ").split()]

#     def display(self):
#         print(self.__sales_figures)


# class HardwareItem(Product, Sales):
#     def __init__(self) -> None:
#         # super().__init__() Ye Pehle super ko hi call krega bs
#         Product.__init__(self)
#         Sales.__init__(self)
#         self.__category = input("Enter Category: ")
#         self.__oem = input("Enter OEM: ")

#     def display(self):
#         # super().display() pehl ko hi call krega bs
#         Product.display(self)
#         Sales.display(self)
#         print(self.__category, self.__oem)


# hw1 = HardwareItem()
# hw1.display()
# hw2 = HardwareItem()
# hw2.display()


# Diamond Problem

# class Base:
#     def display(self):
#         print("In Base")


# class Derived1(Base):
#     def display(self):
#         print("In Dervi 1")


# class Derived2(Base):
#     def display(self):
#         print("Der 2")


# class Derved3(Derived1, Derived2):
#     def display(self):
#         super().display()
#         Derived1.display(self)
#         Derived2.display(self)
#         print(Derved3.__mro__)
# d1=Derved3()
# d1.display()


from abc import ABC, abstractmethod


class Shape(ABC):
    @abstractmethod
    def draw(self):
        pass


class Rectangle(Shape):
    def draw(self):
        print("In Rectangle ")


class Circle(Shape):
    def draw(self):
        print("In Circle")

    def display():
        print("In Circle")


# s=Shape()
c = Circle()
c.draw()
